# %% [markdown]
# <a href="https://colab.research.google.com/github/Liang130520/Tableau/blob/main/Tableau_20221029.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
" Tableau "
# step1 : 開啟資料
# step2 : 確認excel檔內資料的「公式」「定義名稱」是期望的模樣
# step3 : 測試版需關閉 Tableau,才能儲存excel檔, 屆時 Tableau 再重新整理資料即可
" 資料串接 "
# step4 : 將訂單拉至空格, 於訂單(向下箭頭)按開啟 # 21個欄位, 10933筆資料
" 資料合併 "
# step5 : 將人員拉至訂單後方, 作交集 # 23個欄位, 785筆資料
# step6 : 再將退貨拉至人員下方, 與訂單做 Left聯集 # 25個欄位, 10933筆資料
" 資料內容改寫 "
# step7 : 選擇退回, 按右鍵, 選擇別名, 將 null 調整成否
" 資料內容分割 "
# step8 : 選擇客戶ID, 按右鍵, 選擇「分割」, 於最後欄位將出現分割後資料, 可直接於名稱進行改寫「客戶縮寫」, 不需要的欄位進行刪除即可 # 26個欄位, 10933筆資料

"""總表"""
" 工作表 "
# step9 : 進入《工作表》, 一個工作表只能呈現一個圖形, 待圖形皆完成, 再放入《儀表板》內呈現

""" 
資料類型

藍色:維度, 資料分析的方向, 決定橫向或縱向的呈現
綠色:數值, 根據類別判斷數字分布情況
"""
" 度量名稱 "
# step10 : 選擇銷售額, 拉入「標記」「文字」, 再對數量及利潤點擊兩下, 即會呈現度量名稱及相關數值
" 調整文字大小 "
# step11 : 選擇「標記」「文字」, 點選「...」, 調整文字相關選項
" 調整數字格式 "
# step12 : 選擇「度量值」「銷售額」, 按右鍵, 點選格式設定, 選擇貨幣(自訂), 將小數點調成 0 位
" 調整標題格式 "
# step13 : 選擇標題「利潤」, 按右鍵, 點選格式設定, 可選擇字體大小、字體位置、背景顏色、字體顏色
# stop14 : 選擇「格式」「工作簿」, 可進行全工作表設定更動, 無須每個工作表皆操作

"""產品類別的銷售長條圖"""
" 資料排序 "
# step15 : 進入工作表2
# stop16 : 將「子類別」拉入列, 將「銷售額」拉入欄
# step17 : 將滑鼠移至「銷售額」, 出現排序圖形, 點一下大->小, 點兩下小->大, 點三下依據筆畫多寡排序
# step18 : 可點選每個不同類別分別進行排序
" 排序資料上色 "
# step19 : 將「類別」拉入「子類別」前方
# stop20 : 將「類別」拉入「標記」「顏色」
" 依銷售金額多寡區分顏色 "
# step21 : 將「銷售額」拉入「標記」「顏色」, 只會出現一種顏色區分, 顏色由深至淺代表銷售額高至低

"""產品類別的銷售日期分布"""
" 釐清日期型態 "
# step22 : 開啟工作表3, 製作產品類別的銷售趨勢圖
# step23 : 將「訂單日期」拉入欄, 按右鍵, 選擇欲呈現的年月日(較上層的時間呈現無年份排序, 較下層的時間則會有年份排序)
# step24 : 將「訂單日期」選擇 上層 年, 再將另一個「訂單日期」拉入欄, 按右鍵, 選擇 上層 季
" 製作日曆 "
# step25 : 1.單月份 2.橫軸:星期幾 3.縱軸:週 4.內容:天
# step26 : 將「訂單日期」拉入欄, 按右鍵, 選擇上層「工作日」, 將「訂單日期」拉入列, 按右鍵, 選擇上層「週」, 將「訂單日期」拉入標記「文字」, 按右鍵, 選擇上層「天」
" 製作萬年曆日曆 "
# step27 : 將「訂單日期」拉入欄, 按右鍵, 選擇 上層「年」, 將「訂單日期」拉入列, 按右鍵, 選擇上層「月」, 會出現類似萬年曆的資料
" 製作單月份日曆 " # 去除萬年曆日曆「年、月」, 保留日曆「工作日、週」 
# step28 : 將「訂單日期」拉入篩選條件, 選擇「年/月」, 即會呈現所選月份日曆 (若要有缺失資料的日期, 建議與萬年曆連動)
# step29 : 因為是銷售日期分布, 將「銷售額」拉入標記「文字」, 進入文字, 調整文字位置及大小

"""產別類別的銷售趨勢"""
" 知道類別銷售趨勢 "
# step30 : 將「訂單日期」拉入欄, 按右鍵, 選擇 下層「月」, 將「銷售額」拉入列, 將「類別」拉入標記「顏色」
" 知道利潤及銷售額的差異趨勢 "
# step31 : 將「類別」取出, 將利潤拉入銷售額的軸, 將呈現共用軸, 利潤及銷售額將出現於同表中

"""製作儀錶板"""
" 大小調整 "
# step32 : 選擇大小, 「固定尺寸」的解析度較佳, 「自動」不會因應他人解析度變動, 僅為創作者解析度變動
" 儀錶板呈現 "
# step33 : 將左側工作表一一拉入頁面中, 自行做成欲呈現樣態
" 知曉每日銷售情況, 動態變化 "
# step34 : 在上方工具列「儀表板」點選「動作」, 選擇「新增動作」, 點選「篩選條件」
# 篩選條件說明：來源工作表 -> 主要影響工作表, 目標工作表 -> 被影響工作表
# step35 : 來源工作表內選取「產品類別的銷售日期分布」，目標工作表選取「產別類別的銷售趨勢」、「產品類別的銷售長條圖」、「總表」
# step36 : 在「產品類別的銷售日期分布」右側選擇向下箭頭, 點選篩選條件「年/月」, 可於圖表最右側選擇年月份
# step37 : 在最右側的年月份列表中, 按右鍵, 選擇單值(清單), 可限定只選擇單一月份
# step38 : 在最右側的年月份列表中, 按右鍵, 選擇「套用於工作表」, 點選「選取的工作表」, 勾選「產品類別的銷售長條圖」、「總表」

# %%
" 地圖形式 "
# 機場:空運、海運；地區代碼(美國):美國電話區號；僅限數字；CBSA/MSA(美國):由美國行政管理和預算局定義的美國核心基礎統計區域，
# 包括大都市統計區域；城市:全世界人口達到或超過15,000人的城市。名稱以英語、法語、德語、西班牙語、巴西葡萄牙語、日語、韓語和
# 中文簡體 表示；國會選區(美國):美國國會選區；國家:地區 全世界的國家、地區和領地。名稱以英語、法語、德語、西班牙語、巴西葡萄
# 牙語、日語、韓語和中文 簡體 表示。 Tableau 還可識別 FIPS 10 、 ISO 3166 1 alpha 2 以及 ISO 31661 alpha 3 。名稱使用多種格式，
# 包括長名稱、短名稱，以及各種縮寫；郡縣:所選國家地區的二級行政區域。例如，美國的郡 縣、法國的 départements 、德國的 kriese 等。
# 注意： 二級行政區域定義因國家 地區而異。在 Tableau 中，所有二級行政區域都使用“郡 縣”地理角色進行編碼；歐洲NUTS NUTS（地域統計
# 單位命名法 1 3 級代碼。支援代碼和名稱，包括同義詞；緯度:以十進位度數為單位的緯度。只能用於數位欄位。經度以十進位度數為單位的經度。
# 只能用於數位欄位；州省:全世界範圍的州省 市 自治區，以及其他一級行政區域。名稱以英語、法語、德語、西班牙語、巴西葡萄牙語、日語、韓語
# 和中文 簡體 表示。 注意： 某些名稱只能使用其本地形式；郵遞區號:所選國家地區的郵遞區號。例如，美國的五位郵遞區號、澳大利亞的四位郵遞區號、德國的五位郵遞區號等。
"==============================================================================================="

"""地圖"""
# step1 : 選擇「國家/地區」, 按右鍵, 選擇地理角色, 點選國家/地區, 州/省及城市也尋找相對應形式
# step2 : 將「國家/地區」拉至中央, 會出現經緯度的欄列
# step3 : 將「州/省」拉至「標記」, 會出現更多小圈, 右下會出現(1未知)通知
# step4 : 點擊(1未知)通知, 跳出三選項, 選擇編輯位置, 於Hong Kong SAR 後空格填入 Hong Kong按確定即可
# step5 : 可於標記上向下箭頭選擇適當模樣, 選擇地圖
# step6 : 將「銷售額」拉至「標記」「顏色」, 呈現各國家銷售額顏色差異
" 取得銷售額前三國家資訊 "
# step7 : 將「國家」拉入篩選條件, 選擇「頂端」, 「3」、「銷售額」、「總和」

"""地圖雙軸"""
# step8 : 將「國家/地區」拉至中央, 會出現經緯度的欄列
# step9 : 將欄的經度複製到欄
# step10 : 將「銷售額」拉至「標記」「經度(產生)」「顏色」
# step11 : 將「州/省」拉至「標記」「經度(產生)(2)」, 將「利潤」拉至「標記」「經度(產生)(2)」「顏色」, 會出現更多小圈
# step12 : 滑鼠移至後方經度, 按右鍵, 點選雙軸, 兩圖即合為一圖

"""散佈圖"""
# step13 : 將「銷售額」放至欄, 將「利潤」放至列
# step14 : 將「產品ID」放至「標記」, 呈現那些產品賣多虧多, 或賣多賺多
# step15 : 將「類別」放至「標記」「顏色」, 再將「類別」放至「標記」「圖形」, 呈現哪些類別的銷售情況

"""集合"""
# step16 : 選擇「產品ID」, 按右鍵, 選擇「建立」, 點選「集合」, 名稱改為「利潤最高top20的產品」, 至「」# step13 : 將「銷售額」放至欄, 將「利潤」放至列
# step14 : 將「產品ID」放至「標記」, 呈現那些產品賣多虧多, 或賣多賺多
# step15 : 將「類別」放至「標記」「顏色」, 再將「類別」放至「標記」「圖形」, 呈現哪些類別的銷售情況

"""集合"""
" 取高獲利產品 "
# step16 : 選擇「產品ID」, 按右鍵, 選擇「建立」, 點選「集合」, 名稱改為「利潤最高top20的產品」, 至「頂端」選擇「頂端」「20」「利潤」
" 取高銷售產品 "
# step17 : 選擇「產品ID」, 按右鍵, 選擇「建立」, 點選「集合」, 名稱改為「銷售額>=15k的產品」, 至「條件」選擇「銷售額」「總和」「>=」「15000」
" 產品銷售資料呈現"
# step18 : 將「利潤最高top20的產品」放至列, 再將「銷售額>=15k的產品」放至欄, 後將「產品ID」放至列
# step19 : 內為符合條件, 外為不符條件, 欲取得「取銷售高且獲利高的產品」, 即欲取得內內產品
" 取銷售高且獲利高的產品 "
# step20 : 按 CTRL 選取「利潤最高top20的產品」及「銷售額>=15k的產品」, 按右鍵, 點選「建立合併集合」, 作交集動作
# step21 : 將「取銷售高且獲利高的產品」放入列, 再將「產品ID」放入列, 可取得符合條件之產品ID及不符合條件之ID
# step22 : 將「取銷售高且獲利高的產品」放入篩選條件, 選擇內, 即可取得符合條件之產品ID
" 取得銷售高且獲利高的產品數量 "
# step23 : 將「產品ID」放入「標記」, 按右鍵, 選擇「度量」「計數(不同)」, 即可呈現產品數量

"""圓餅圖"""
# step24 : 「標記」選擇「圓餅圖」
# step25 : 將「人」拉至「標記」「顏色」, 將呈現4等分圓餅圖, 因尚未知曉如何分此4人比例
" 地區負責人的訂單比例 "
# step26 : 將「訂單ID」拉至「標記」「角度」, 按右鍵, 選擇「度量」「計數(不同)」, 即會呈現按比例分的圓餅圖
" 加入名稱及數字 "
# step27 : 按住 CTRL, 將「人」&「相異計數(訂單ID)」拉至「標記」「標籤」, 即可取得名字及數字
" 將文字顏色與圓餅圖統一 "
# step28 : 選擇「標記」「標籤」, 選擇「字體」, 點選「符合標記色彩」

"""樹狀圖""" # 資訊量過多. 不便使用圓餅圖複雜呈現
# step29 : 將「國家/地區」拉至「標記」「詳細資料」, 標記選擇「方形」
# step30 : 將「銷售額」拉至「標記」「大小」, 再將「國家/地區」拉至「標記」「顏色」
# step31 : 將「銷售額」及「國家/地區」拉至「標記」「標籤」

"公式"
# 數位函數, 字串函數, 日期函數, 類型轉換, 邏輯函數, 彙總函數, 直通函數, 使用者函數, 表計算函數, 空間函數, 預測建模函數, 其他函數
" 建立計算欄位 "
# step32 : 在搜尋右側向下箭頭點選【建立計算欄位】／選擇資料, 按右鍵, 選【建立】, 點選【計算欄位】

"""民國年轉西元年"""
# step33 : 將【資料更新日】拉至列
# 若格式固定, ex:xxx/01/01, 可利用函式 LEFT(3), 代表自左邊數來第三位更新
# step34 : 建立計算欄位, 使用函式 SPLIT(字串, 分隔符號, # 數位函數, 字串函數, 日期函數, 類型轉換, 邏輯函數, 彙總函數, 直通函數, 使用者函數, 表計算函數, 空間函數, 預測建模函數, 其他函數
" 建立計算欄位 "
# step32 : 在搜尋右側向下箭頭選擇# 數位函數, 字串函數, 日期函數, 類型轉換, 邏輯函數, 彙總函數, 直通函數, 使用者函數, 表計算函數, 空間函數, 預測建模函數, 其他函數
" 建立計算欄位 "
# step32 : 在搜尋右側向下箭頭點選【建立計算欄位】／選擇資料, 按右鍵, 選【建立】, 點選【計算欄位】
"民國年轉西元年"
# step33 : 將【資料更新日】拉至列
" #1抓出民國年 "
# 若格式固定, ex:xxx/01/01, 可利用函式 LEFT(3), 代表自左邊數來第三位更新
# step34 : 建立計算欄位, 使用函式 SPLIT(字串, 分隔符號, 權杖編號), 字串可直接拉資料表中資料進來, 資料表需[], 分隔符號需'', 權杖編號為遇到分隔符號取第幾個
# SPLIT([資料更新日],'/',1)
# step35 : 將 #1抓出民國年 拉至列
" #2做類型轉換(INT) "
# step36 : 建立計算欄位, 使用函式 INT(運算式), INT([#1抓出民國年])+1911
# step37 : 數值無法填入欄列, 將其拉至上方維度, 方可做列表
# step38 : 將 #2做類型轉換(INT) 拉至列
" #3抓出月日 " # 欲抓出2xxx/01/01
# step36 : SPLIT不便操作, 採用MID(字串, 開始, [長度]) -> MID([資料更新日],4)
" #4合併年月日 "
# step39 : STR([#2做類型轉換(INT)])+[#3抓出月日]
# step40 : 最後轉成日期型態 DATE(STR([#2做類型轉換(INT)])+[#3抓出月日])

"""邏輯公式"""
" #1邏輯判斷 "
# IF 條件判斷 THEN 給定義
# ELSEIF 條件判斷 THEN 給定義
# ELSE 給定義
# END
# step41 : 建立計算欄位, IF [利潤]>=0 THEN 'Good'  ELSE 'Bad'  END／IF [利潤]>=0 THEN 'Good'  ELSEIF [利潤]<0 THEN 'Bad'  END
# step42 : 將【訂單ID】及【#1邏輯判斷】拉至列, 會發現同個訂單ID出現 Good & Bad, 將【利潤】拉至【標記】【文字】, 再將產品ID拉至列, 可發現訂單內有不只一項產品, 判斷依據為單筆利潤, 非整筆利潤
" #2邏輯判斷(聚合) " # 希望呈現每筆訂單的利潤, 非訂單中單項利潤
# step43 : 建立計算欄位, IF SUM([利潤])>=0 THEN 'Good'  ELSE 'Bad'  END

"""計算毛利率"""
" #1毛利率(不聚合) "
# step44 : 建立計算欄位, [利潤]/[銷售額]
# step45 : 將【#1毛利率(不聚合)】放入【標記】【文字】, 得到749.7, 為所有單項毛利率加總, 非意願取得之資料, 故進行以下更動
" #2毛利率(聚合) " 
# step46 : 建立計算欄位, SUM([利潤])/SUM([銷售額]) -> 總利潤/總銷售額, 即為時間段內毛利率
# step47 : 將【#2毛利率(聚合)】放入【標記】【文字】, 得到0.1211
# step48 : 滑鼠右鍵【#2毛利率(聚合)】, 點選格式, 左側選擇數字, """計算毛利率"""
" #1毛利率(不聚合) "
# step44 : 建立計算欄位, [利潤]/[銷售額]
# step45 : 將【#1毛利率(不聚合)】放入【標記】【文字】, 得到749.7, 為所有單項毛利率加總, 非意願取得之資料, 故進行以下更動
" #2毛利率(聚合) " 
# step46 : 建立計算欄位, SUM([利潤])/SUM([銷售額]) -> 總利潤/總銷售額, 即為時間段內毛利率
# step47 : 將【#2毛利率(聚合)】放入【標記】【文字】, 得到0.1211
# step48 : 滑鼠右鍵【#2毛利率(聚合)】, 點選格式, 左側選擇【預設值】【數字】【百分比】,呈現百分比小數點後1位的數值
